# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import SGDClassifier
from time import time
from IPython.display import display
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
import xgboost as xgb
import lightgbm as lgb
from scipy.stats import randint as sp_randint
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score, fbeta_score, roc_curve, auc, roc_auc_score, precision_recall_fscore_support
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

import warnings
warnings.filterwarnings('ignore')


sns.set_theme()

# %% [markdown]
# **Importing Dataset**

# %%
df = pd.read_csv('dataset/default of credit card clients.csv')
df.columns = df.iloc[0]
df = df[1:].drop(labels=['ID'],axis=1)
df.head()
# Out:
# 0 LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  ...  \
# 1     20000   2         2        1  24     2     2    -1    -1    -2  ...
# 2    120000   2         2        2  26    -1     2     0     0     0  ...
# 3     90000   2         2        2  34     0     0     0     0     0  ...
# 4     50000   2         2        1  37     0     0     0     0     0  ...
# 5     50000   1         2        1  57    -1     0    -1     0     0  ...
#
# 0 BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# 1         0         0         0        0      689        0        0        0
# 2      3272      3455      3261        0     1000     1000     1000        0
# 3     14331     14948     15549     1518     1500     1000     1000     1000
# 4     28314     28959     29547     2000     2019     1200     1100     1069
# 5     20940     19146     19131     2000    36681    10000     9000      689
#
# 0 PAY_AMT6 default payment next month
# ...

# %% [markdown]
# # **Exploring Dataset**
#
# 1.Count of Null values
#
# 2.Shape of dataset
#
# 3.Uniques values

# %% [markdown]
# 1. Count of Null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  object
#  1   SEX                         30000 non-null  object
#  2   EDUCATION                   30000 non-null  object
#  3   MARRIAGE                    30000 non-null  object
#  4   AGE                         30000 non-null  object
#  5   PAY_0                       30000 non-null  object
#  6   PAY_2                       30000 non-null  object
#  7   PAY_3                       30000 non-null  object
#  8   PAY_4                       30000 non-null  object
#  9   PAY_5                       30000 non-null  object
#  10  PAY_6                       30000 non-null  object
#  11  BILL_AMT1                   30000 non-null  object
#  12  BILL_AMT2                   30000 non-null  object
# ...

# %%
data = df

# %%
has_nan = data.isna().any().any()
if has_nan:
    print("The DataFrame contains NaN values.")
else:
    print("The DataFrame does not contain any NaN values.")
# Out:
# The DataFrame does not contain any NaN values.

# %% [markdown]
# 2. Shape of the Dataset

# %%
data.shape
# Out:
# (30000, 24)

# %% [markdown]
# 3. Uniques values
#
# Verifying whether there are columns containing only one unique value, as they will have no impact on our analysis.

# %%
# No unique values found

# %%
data.nunique(dropna=True)
# Out:
# 0
# LIMIT_BAL       81
# SEX              2
# EDUCATION        4
# MARRIAGE         4
# AGE             56
# PAY_1           11
# PAY_2           11
# PAY_3           11
# PAY_4           11
# PAY_5           10
# PAY_6           10
# BILL_AMT1    22723
# BILL_AMT2    22346
# BILL_AMT3    22026
# BILL_AMT4    21548
# BILL_AMT5    21010
# BILL_AMT6    20604
# PAY_AMT1      7943
# PAY_AMT2      7899
# PAY_AMT3      7518
# PAY_AMT4      6937
# PAY_AMT5      6897
# PAY_AMT6      6939
# def_pay          2
# dtype: int64

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (29965, 24)

# %% [markdown]
# # **Statistics of Dataset**
#
# ## 1. *Descriptive statistics*
#
# Summarizing the distribution of the numerical variables.

# %%
df.describe()
# Out:
# 0           LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
# 0             PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %% [markdown]
# ## 2. Unique Value Count from each Column:

# %%
for col in df.columns:
    print(f'{col} : {len(set(df[col]))}')
# Out:
# LIMIT_BAL : 81
# SEX : 2
# EDUCATION : 7
# MARRIAGE : 4
# AGE : 56
# PAY_0 : 11
# PAY_2 : 11
# PAY_3 : 11
# PAY_4 : 11
# PAY_5 : 10
# PAY_6 : 10
# BILL_AMT1 : 22723
# BILL_AMT2 : 22346
# BILL_AMT3 : 22026
# BILL_AMT4 : 21548
# BILL_AMT5 : 21010
# BILL_AMT6 : 20604
# PAY_AMT1 : 7943
# PAY_AMT2 : 7899
# PAY_AMT3 : 7518
# PAY_AMT4 : 6937
# PAY_AMT5 : 6897
# PAY_AMT6 : 6939
# default payment next month : 2

# %% [markdown]
# ## *Descriptive statistics of similar Groups*

# %% [markdown]
# ## 3. *Descriptive statistics of SEX	EDUCATION	MARRIAGE*

# %%
df.iloc[:,1:4].describe()
# Out:
# 0               SEX     EDUCATION      MARRIAGE
# count  30000.000000  30000.000000  30000.000000
# mean       1.603733      1.853133      1.551867
# std        0.489129      0.790349      0.521970
# min        1.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000
# 50%        2.000000      2.000000      2.000000
# 75%        2.000000      2.000000      2.000000
# max        2.000000      6.000000      3.000000

# %% [markdown]
# ## 4. *Descriptive statistics of PAY_0->PAY_6*

# %% [markdown]
# ## 5. *Descriptive statistics of Bill amt 1-> Bill amt 6*

# %% [markdown]
# ## 4. *Descriptive statistics of PAY_amt1->PAY_6*

# %%
df.iloc[:,5:11].describe()
# Out:
# 0             PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
# 0             PAY_6
# count  30000.000000
# mean      -0.291100
# std        1.149988
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
df.iloc[:,11:17].describe()
# Out:
# 0          BILL_AMT1      BILL_AMT2     BILL_AMT3      BILL_AMT4  \
# count   30000.000000   30000.000000  3.000000e+04   30000.000000
# mean    51223.330900   49179.075167  4.701315e+04   43262.948967
# std     73635.860576   71173.768783  6.934939e+04   64332.856134
# min   -165580.000000  -69777.000000 -1.572640e+05 -170000.000000
# 25%      3558.750000    2984.750000  2.666250e+03    2326.750000
# 50%     22381.500000   21200.000000  2.008850e+04   19052.000000
# 75%     67091.000000   64006.250000  6.016475e+04   54506.000000
# max    964511.000000  983931.000000  1.664089e+06  891586.000000
#
# 0          BILL_AMT5      BILL_AMT6
# count   30000.000000   30000.000000
# mean    40311.400967   38871.760400
# std     60797.155770   59554.107537
# min    -81334.000000 -339603.000000
# 25%      1763.000000    1256.000000
# 50%     18104.500000   17071.000000
# 75%     50190.500000   49198.250000
# max    927171.000000  961664.000000

# %%
df.iloc[:,17:23].describe()
# Out:
# 0           PAY_AMT1      PAY_AMT2      PAY_AMT3       PAY_AMT4  \
# count   30000.000000  3.000000e+04   30000.00000   30000.000000
# mean     5663.580500  5.921163e+03    5225.68150    4826.076867
# std     16563.280354  2.304087e+04   17606.96147   15666.159744
# min         0.000000  0.000000e+00       0.00000       0.000000
# 25%      1000.000000  8.330000e+02     390.00000     296.000000
# 50%      2100.000000  2.009000e+03    1800.00000    1500.000000
# 75%      5006.000000  5.000000e+03    4505.00000    4013.250000
# max    873552.000000  1.684259e+06  896040.00000  621000.000000
#
# 0           PAY_AMT5       PAY_AMT6
# count   30000.000000   30000.000000
# mean     4799.387633    5215.502567
# std     15278.305679   17777.465775
# min         0.000000       0.000000
# 25%       252.500000     117.750000
# 50%      1500.000000    1500.000000
# 75%      4031.500000    4000.000000
# max    426529.000000  528666.000000

# %%
print(df.iloc[:,0].describe())
print()
print(df.iloc[:,23].describe())
# Out:
# count      30000.000000
# mean      167484.322667
# std       129747.661567
# min        10000.000000
# 25%        50000.000000
# 50%       140000.000000
# 75%       240000.000000
# max      1000000.000000
# Name: LIMIT_BAL, dtype: float64
#
# count    30000.000000
# mean         0.221200
# std          0.415062
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: def_pay, dtype: float64

# %%
print(f"{df['def_pay'].sum()/300}% of the def_pay is 1")
# Out:
# 22.12% of the def_pay is 1

# %% [markdown]
# # Data Preprocessing (Preparing Dataset)

# %% [markdown]
# # 1.Replace PAY_0 to PAY_1

# %%
df = df.rename(columns={'default payment next month': 'def_pay', 'PAY_0': 'PAY_1'})
df
# Out:
# 0      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 1        20000.0    2          2         1   24      2      2     -1     -1
# 2       120000.0    2          2         2   26     -1      2      0      0
# 3        90000.0    2          2         2   34      0      0      0      0
# 4        50000.0    2          2         1   37      0      0      0      0
# 5        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996   220000.0    1          3         1   39      0      0      0      0
# 29997   150000.0    1          3         2   43     -1     -1     -1     -1
# 29998    30000.0    1          2         2   37      4      3      2     -1
# 29999    80000.0    1          3         1   41      1     -1      0      0
# 30000    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %% [markdown]
# # 2.Datatypes are not set.
# ## Set datatype based to foat64 and int64 according to column data

# %%
df = df.astype(np.float64)
# df.iloc[:,1:11] = df.iloc[:,1:11].astype(np.int64)
for i in range(10):
    df[df.columns[i+1]] = df[df.columns[i+1]].astype(np.int64)
df[df.columns[-1]] = df[df.columns[-1]].astype(np.int64)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  float64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  float64
#  12  BILL_AMT2                   30000 non-null  float64
# ...

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ## 1.Countplots (sex,education,marriage)

# %%
print("--------------------------------------")
for i in range(3):
    print(df.iloc[:,i+1:i+2].value_counts())
    print("--------------------------------------")

for i in range(3):
    df.iloc[:,i+1:i+2].value_counts().plot(kind = 'barh')
    plt.show()
# Out:
# --------------------------------------
# SEX
# 2      18112
# 1      11888
# dtype: int64
# --------------------------------------
# EDUCATION
# 2            14030
# 1            10585
# 3             4917
# 5              280
# 4              123
# 6               51
# 0               14
# dtype: int64
# --------------------------------------
# MARRIAGE
# 2           15964
# 1           13659
# 3             323
# 0              54
# dtype: int64
# --------------------------------------

# %% [markdown]
# ## 2.Countplots (pay1 -> 6)

# %%
print("--------------------------------------")
for i in range(6):
    print(df.iloc[:,i+5:i+6].value_counts())
    print("--------------------------------------")


for i in range(6):
    df.iloc[:,i+5:i+6].value_counts().plot(kind = 'barh')
    plt.show()
# Out:
# --------------------------------------
# PAY_1
#  0       14737
# -1        5686
#  1        3688
# -2        2759
#  2        2667
#  3         322
#  4          76
#  5          26
#  8          19
#  6          11
#  7           9
# dtype: int64
# --------------------------------------
# PAY_2
#  0       15730
# -1        6050
#  2        3927
# -2        3782
#  3         326
#  4          99
#  1          28
#  5          25
#  7          20
#  6          12
#  8           1
# dtype: int64
# --------------------------------------
# PAY_3
#  0       15764
# -1        5938
# -2        4085
#  2        3819
#  3         240
#  4          76
#  7          27
#  6          23
#  5          21
#  1           4
#  8           3
# dtype: int64
# --------------------------------------
# PAY_4
#  0       16455
# -1        5687
# -2        4348
#  2        3159
#  3         180
#  4          69
#  7          58
#  5          35
#  6           5
#  1           2
#  8           2
# ...

# %% [markdown]
# # 3. Heatmap

# %%
cor=df.iloc[:,:-1].corr()
plt.figure(figsize=(25,25))
sns.heatmap(cor, cmap='Blues')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# **Outcomes**
#
# 1. Several features have very strong correlation with each other. We may remove them if they are close to 1.

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## 3. Correlation Strongly correlated elements

# %%
cor = df.iloc[:,:-1].corr()
# Convert the correlation matrix into a Series
cor_series = cor.unstack()
# Sort the correlation values in descending order
sorted_cor = cor_series.sort_values(ascending=False)
# Filter out the pairs with perfect correlation (correlation of 1) and self-correlations
sorted_cor = sorted_cor[(sorted_cor < 1) & (sorted_cor > -1)]
sorted_cor
# Out:
# BILL_AMT1  BILL_AMT2    0.951484
# BILL_AMT2  BILL_AMT1    0.951484
# BILL_AMT6  BILL_AMT5    0.946197
# BILL_AMT5  BILL_AMT6    0.946197
# BILL_AMT4  BILL_AMT5    0.940134
#                           ...
# LIMIT_BAL  PAY_3       -0.286123
# PAY_2      LIMIT_BAL   -0.296382
# LIMIT_BAL  PAY_2       -0.296382
# MARRIAGE   AGE         -0.414170
# AGE        MARRIAGE    -0.414170
# Length: 506, dtype: float64

# %% [markdown]
# # 4. Heatmap (Pay)

# %%
var = ['PAY_1', 'PAY_2','PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

plt.figure(figsize = (8,8))
corr = df[var].corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# # 5. Heatmap (BILL_AMT)

# %%
var = ['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6']

plt.figure(figsize = (8,8))
corr = df[var].corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# # 6. Heatmap (PAY_AMT)

# %%
var = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
plt.figure(figsize = (8,8))
corr = df[var].corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# # 7. Boxplot over feature1,feature2 with feature3 as hue

# %%
def boxplot_variation(feature1, feature2, feature3, width=16, type_="box"):
    fig, ax1 = plt.subplots(ncols=1, figsize=(width,6))
    if(type_=="box"):
        s = sns.boxplot(ax = ax1, x=feature1, y=feature2, hue=feature3,
                    data=df, palette="PRGn",showfliers=False)
    else:
        s = sns.violinplot(ax = ax1, x=feature1, y=feature2, hue=feature3,
            data=df, palette="PRGn",showfliers=False)
    s.set_xticklabels(s.get_xticklabels(),rotation=90)
    plt.show()

# %% [markdown]
# # 8. Violinplot over 'MARRIAGE','AGE', 'SEX'

# %%
boxplot_variation('MARRIAGE','AGE', 'SEX',15,type_="violin")

# %% [markdown]
# # 9. Violinplot over 'EDUCATION','AGE', 'MARRIAGE'

# %%
boxplot_variation('EDUCATION','AGE', 'MARRIAGE',16)

# %% [markdown]
# # 10. Boxplot over 'AGE','LIMIT_BAL','SEX'

# %%
boxplot_variation('AGE','LIMIT_BAL', 'SEX',25)

# %% [markdown]
# # 11. Boxplot over 'MARRIAGE','LIMIT_BAL','EDUCATION'

# %%
boxplot_variation('MARRIAGE','LIMIT_BAL', 'EDUCATION',20)

# %% [markdown]
# **THE BELOW DATA WAS GIVEN DURING THE DATASET DESCRIPTION:**
#
# 1. LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# 2. SEX: Gender (1=male, 2=female)
# 3. EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# 4. MARRIAGE: Marital status (1=married, 2=single, 3=others)

# %% [markdown]
# # Data Pre-processing
# ## 4. group categories

# %% [markdown]
# ### We can group categories 4,5, and 6 as 'others'
# ### We can group categories 4,5, and 6 as 'others'

# %%
fil = (df.EDUCATION == 5) | (df.EDUCATION == 6) | (df.EDUCATION == 0)
df.loc[fil, 'EDUCATION'] = 4
df.EDUCATION.value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %% [markdown]
# # Split test train data with equal ratio of classes

# %%
# General Code to predict and record the model performanceX = df.iloc[:,:-1]
y = df.iloc[:,-1]

# Split the data with an equal ratio of classes
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # StandardScaler applied to Data

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Evaluators :

# %% [markdown]
# # General Code to predict and record the model performance

# %%
def train_predict(learner, sample_size, X_train, y_train, X_test, y_test): 
    results = {}

    predictions_train = learner.predict(X_train)
    predictions_test = learner.predict(X_test)
    
    results['acc_train'] = accuracy_score(y_train,predictions_train)
    results['acc_test'] = accuracy_score(y_test,predictions_test)

    results['prec_train'] = precision_score(y_train,predictions_train)
    results['prec_test'] = precision_score(y_test,predictions_test)

    results['f1_train'] = f1_score(y_train,predictions_train)
    results['f1_test'] = f1_score(y_test,predictions_test)
    
    results['recall_train'] = recall_score(y_train, predictions_train)
    results['recall_test'] = recall_score(y_test, predictions_test)
    
    try:
        y_prob_train = learner.predict_proba(X_train)[:, 1]
        y_prob_test = learner.predict_proba(X_test)[:, 1]
        results['auc_train'] = roc_auc_score(y_train,y_prob_train)
        results['auc_test'] = roc_auc_score(y_test,y_prob_test)
    except:
        print("Probability cannot be found for this model.")
    
    results['f_train'] = fbeta_score(y_train,predictions_train,beta=1)
    results['f_test'] = fbeta_score(y_test,predictions_test,beta=1)
    
    results['classification_report_train'] = classification_report(y_train, predictions_train)
    results['classification_report_test'] = classification_report(y_test, predictions_test)
    
    for x in results:
        print(f"{x} : {results[x]}")
    
    return results

# %% [markdown]
# **Outcomes**
#
# 1. accuracy, f1, precision, recall with auroc is recorded
# 2. A classification report is also made.
# 3. These are made and recorded in form of a set for any model created from hereon.

# %% [markdown]
# # Confusion Matrix

# %%
def plot_cm(y_test,y_pred):
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %% [markdown]
# # CLASSIFICATION PROBLEMS:

# %% [markdown]
# # LogisticRegression

# %%
classifier = LogisticRegression(random_state = 42,penalty='l2',C=0.001,solver='lbfgs')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l2',C=0.01,solver='lbfgs')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l2',C=0.1,solver='lbfgs')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l2',C=1,solver='lbfgs')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l2',C=10,solver='lbfgs')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l1',C=0.001,solver='liblinear')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l1',C=0.01,solver='liblinear')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l1',C=0.1,solver='liblinear')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l1',C=1,solver='liblinear')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l1',C=10,solver='liblinear')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = LogisticRegression(random_state = 42,penalty='l1',C=100,solver='liblinear')
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

#BEST FIT
logisticRegression_classifier = LogisticRegression(random_state = 42,penalty='l2',C=100,solver='lbfgs')
logisticRegression_classifier.fit(X_train_scaled, y_train)
predictions = logisticRegression_classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))

# %% [markdown]
# ### Model with the best fit :

# %%
logisticRegression_classifier.fit(X_train_scaled,y_train)
logisticRegression_result = train_predict(logisticRegression_classifier, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test,logisticRegression_classifier.predict(X_test_scaled))
# Out:
# acc_train : 0.8114583333333333
# acc_test : 0.808
# prec_train : 0.7137404580152672
# prec_test : 0.6889848812095032
# f1_train : 0.36651266974660507
# f1_test : 0.35642458100558655
# recall_train : 0.2465624411376907
# recall_test : 0.24039186134137153
# auc_train : 0.7280494522053239
# auc_test : 0.7075166531716859
# f_train : 0.36651266974660507
# f_test : 0.35642458100558655
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89     18691
#            1       0.71      0.25      0.37      5309
#
#     accuracy                           0.81     24000
#    macro avg       0.77      0.61      0.63     24000
# weighted avg       0.80      0.81      0.77     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      4673
#            1       0.69      0.24      0.36      1327
#
# ...

# %% [markdown]
# # SVC

# %%
kernel_svm = SVC(kernel='rbf',C=1.0,gamma='scale')
kernel_svm.fit(X_train_scaled, y_train)
predictions = kernel_svm.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8163333333333334

# %%
kernel_svm_result = train_predict(kernel_svm, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test,kernel_svm.predict(X_test_scaled))
# Out:
# Probability cannot be found for this model.
# acc_train : 0.825375
# acc_test : 0.8163333333333334
# prec_train : 0.707037037037037
# prec_test : 0.6666666666666666
# f1_train : 0.4767136970907729
# f1_test : 0.44955044955044954
# recall_train : 0.3595780749670371
# recall_test : 0.33911077618688773
# f_train : 0.4767136970907729
# f_test : 0.44955044955044954
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90     18691
#            1       0.71      0.36      0.48      5309
#
#     accuracy                           0.83     24000
#    macro avg       0.77      0.66      0.69     24000
# weighted avg       0.81      0.83      0.80     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.67      0.34      0.45      1327
#
#     accuracy                           0.82      6000
# ...

# %% [markdown]
# # Linear SVM

# %%
linear_svm = SVC(kernel='linear',C=1.0,gamma='scale')
linear_svm.fit(X_train_scaled, y_train)
predictions = linear_svm.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.808

# %%
linear_svm_result = train_predict(linear_svm, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test,linear_svm.predict(X_test_scaled))
# Out:
# Probability cannot be found for this model.
# acc_train : 0.809875
# acc_test : 0.808
# prec_train : 0.7056229327453142
# prec_test : 0.6834381551362684
# f1_train : 0.359399129580233
# f1_test : 0.36141906873614194
# recall_train : 0.24110001883593898
# recall_test : 0.24566691785983422
# f_train : 0.359399129580233
# f_test : 0.36141906873614194
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89     18691
#            1       0.71      0.24      0.36      5309
#
#     accuracy                           0.81     24000
#    macro avg       0.76      0.61      0.62     24000
# weighted avg       0.79      0.81      0.77     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      4673
#            1       0.68      0.25      0.36      1327
#
#     accuracy                           0.81      6000
# ...

# %% [markdown]
# # Sigmoid SVM

# %%
sigmoid_svm = SVC(kernel='sigmoid',C=1.0,gamma='scale')
sigmoid_svm.fit(X_train_scaled, y_train)
predictions = sigmoid_svm.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.6963333333333334

# %% [markdown]
# # Naive Bayes

# %%
gaussianNB = GaussianNB()

# %%
gaussianNB.fit(X_train_scaled,y_train)
gaussianNB_result = train_predict(gaussianNB, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test,gaussianNB.predict(X_test_scaled))
# Out:
# acc_train : 0.7614166666666666
# acc_test : 0.7521666666666667
# prec_train : 0.4687827519089684
# prec_test : 0.45085995085995084
# f1_train : 0.5223556890223556
# f1_test : 0.49678510998307956
# recall_train : 0.5897532491994726
# recall_test : 0.5531273549359458
# auc_train : 0.7375060136488855
# auc_test : 0.7246595789662786
# f_train : 0.5223556890223556
# f_test : 0.49678510998307956
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84     18691
#            1       0.47      0.59      0.52      5309
#
#     accuracy                           0.76     24000
#    macro avg       0.67      0.70      0.68     24000
# weighted avg       0.78      0.76      0.77     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84      4673
#            1       0.45      0.55      0.50      1327
#
# ...

# %% [markdown]
# # KNN

# %%
kNeighborsClassifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)

# %%
kNeighborsClassifier.fit(X_train_scaled,y_train)
kNeighborsClassifier_result = train_predict(kNeighborsClassifier, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test,kNeighborsClassifier.predict(X_test_scaled))
# Out:
# acc_train : 0.841
# acc_test : 0.7918333333333333
# prec_train : 0.71821104940076
# prec_test : 0.5454545454545454
# f1_train : 0.5628865979381443
# f1_test : 0.4283752860411899
# recall_train : 0.4627990205311735
# recall_test : 0.35267520723436324
# auc_train : 0.8796642946108142
# auc_test : 0.7010633324469273
# f_train : 0.5628865979381443
# f_test : 0.4283752860411899
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90     18691
#            1       0.72      0.46      0.56      5309
#
#     accuracy                           0.84     24000
#    macro avg       0.79      0.71      0.73     24000
# weighted avg       0.83      0.84      0.83     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87      4673
#            1       0.55      0.35      0.43      1327
#
# ...

# %% [markdown]
# # Bagging

# %%
baggingClassifier = BaggingClassifier(random_state=42)

# %%
baggingClassifier.fit(X_train_scaled,y_train)
baggingClassifier_result = train_predict(baggingClassifier, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test, baggingClassifier.predict(X_test_scaled))
# Out:
# acc_train : 0.9807083333333333
# acc_test : 0.8033333333333333
# prec_train : 0.9938850387280881
# prec_test : 0.5991902834008097
# f1_train : 0.9546744982868332
# f1_test : 0.4294003868471954
# recall_train : 0.918440384253155
# recall_test : 0.33458929917106256
# auc_train : 0.9991501052211569
# auc_test : 0.7194130659042608
# f_train : 0.9546744982868332
# f_test : 0.4294003868471954
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     18691
#            1       0.99      0.92      0.95      5309
#
#     accuracy                           0.98     24000
#    macro avg       0.99      0.96      0.97     24000
# weighted avg       0.98      0.98      0.98     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      4673
#            1       0.60      0.33      0.43      1327
#
# ...

# %% [markdown]
# # SGD

# %%
sgdClassifier = SGDClassifier()

# %%
sgdClassifier.fit(X_train_scaled,y_train)
sgdClassifier_result = train_predict(sgdClassifier, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test, sgdClassifier.predict(X_test_scaled))
# Out:
# Probability cannot be found for this model.
# acc_train : 0.7889583333333333
# acc_test : 0.7885
# prec_train : 0.715547703180212
# prec_test : 0.6933333333333334
# f1_train : 0.13787234042553193
# f1_test : 0.14082599864590387
# recall_train : 0.07628555283480881
# recall_test : 0.07837226827430294
# f_train : 0.13787234042553193
# f_test : 0.14082599864590387
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88     18691
#            1       0.72      0.08      0.14      5309
#
#     accuracy                           0.79     24000
#    macro avg       0.75      0.53      0.51     24000
# weighted avg       0.77      0.79      0.72     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88      4673
#            1       0.69      0.08      0.14      1327
#
#     accuracy                           0.79      6000
# ...

# %% [markdown]
# # DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(max_depth=10, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.8106666666666666

# %%
classifier = DecisionTreeClassifier(max_depth=100, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.7158333333333333

# %%
classifier = DecisionTreeClassifier(max_depth=100, criterion='entropy', random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.72

# %%
classifier = DecisionTreeClassifier(max_depth=8, criterion='entropy', random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.8148333333333333

# %%
classifier = DecisionTreeClassifier(max_depth=8, criterion='entropy',max_leaf_nodes=20, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
accuracy_score(y_true = y_test, y_pred = predictions)
# Out:
# 0.8161666666666667

# %%
classifier = DecisionTreeClassifier(max_depth=8, criterion='entropy',max_leaf_nodes=20,min_samples_split=5, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = DecisionTreeClassifier(max_depth=8, criterion='entropy',max_leaf_nodes=20,min_samples_split=25, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8161666666666667
# 0.8161666666666667

# %%
classifier = DecisionTreeClassifier(max_depth=8, criterion='entropy',max_leaf_nodes=10,min_samples_split=5, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))

classifier = DecisionTreeClassifier(max_depth=8, criterion='entropy',max_leaf_nodes=10, random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8168333333333333
# 0.8168333333333333

# %%
classifier = DecisionTreeClassifier(max_depth=5, criterion='gini', random_state=42) 
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8171666666666667

# %%
classifier = DecisionTreeClassifier(max_depth=8, criterion='gini',max_leaf_nodes=20, random_state=42) 
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8186666666666667

# %% [markdown]
# ### BEST MODEL for DecisionTreeClassifier :

# %%
decision_classifier = DecisionTreeClassifier(max_depth=8, criterion='gini',max_leaf_nodes=20, random_state=42) 
decision_classifier.fit(X_train, y_train)
predictions = decision_classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8186666666666667

# %%
decision_classifier_result = train_predict(decision_classifier, X_train.shape[0], X_train, y_train, X_test, y_test)
plot_cm(y_test,decision_classifier.predict(X_test))
# Out:
# acc_train : 0.823125
# acc_test : 0.8186666666666667
# prec_train : 0.6816939890710383
# prec_test : 0.6621438263229308
# f1_train : 0.4846424669175671
# f1_test : 0.47286821705426363
# recall_train : 0.37596534187229236
# recall_test : 0.3677467972871138
# auc_train : 0.7711730349813046
# auc_test : 0.7496270402322438
# f_train : 0.4846424669175671
# f_test : 0.47286821705426363
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89     18691
#            1       0.68      0.38      0.48      5309
#
#     accuracy                           0.82     24000
#    macro avg       0.76      0.66      0.69     24000
# weighted avg       0.81      0.82      0.80     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.66      0.37      0.47      1327
#
# ...

# %% [markdown]
# #### note: STANDARDSCALER MAKES NO DIFFERENCE AT ALL

# %% [markdown]
# # RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state = 42)
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8125

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state = 42)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8125

# %%
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.805

# %%
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8046666666666666

# %%
classifier = RandomForestClassifier(n_estimators = 50, criterion = 'entropy', random_state = 42)
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8111666666666667

# %%
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'gini', random_state = 42)
classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8133333333333334

# %%
classifier = RandomForestClassifier(n_estimators = 100, max_depth=20, criterion = 'gini', min_samples_leaf=4, random_state = 42)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8143333333333334

# %% [markdown]
# ### Best Performer Model :

# %%
randomForest_classifier = RandomForestClassifier(n_estimators = 100, max_depth=20, criterion = 'gini', random_state = 42)
randomForest_classifier.fit(X_train, y_train)
predictions = randomForest_classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8178333333333333

# %%
randomForest_classifier_result = train_predict(randomForest_classifier, X_train.shape[0], X_train, y_train, X_test, y_test)
plot_cm(y_test, randomForest_classifier.predict(X_test))
# Out:
# acc_train : 0.94925
# acc_test : 0.8178333333333333
# prec_train : 0.9995115995115995
# prec_test : 0.6620498614958449
# f1_train : 0.8704806465333901
# f1_test : 0.4665690580771108
# recall_train : 0.770954982105858
# recall_test : 0.3602110022607385
# auc_train : 0.9970311351490562
# auc_test : 0.7593735824021368
# f_train : 0.8704806465333901
# f_test : 0.4665690580771108
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     18691
#            1       1.00      0.77      0.87      5309
#
#     accuracy                           0.95     24000
#    macro avg       0.97      0.89      0.92     24000
# weighted avg       0.95      0.95      0.95     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.66      0.36      0.47      1327
#
# ...

# %% [markdown]
# # BOOSTERS:

# %% [markdown]
# ## ADABOOST

# %%
classifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME.R',
                         learning_rate=1,
                             n_estimators=5)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8163333333333334

# %%
classifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME.R',
                         learning_rate=0.8,
                             n_estimators=5)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8191666666666667

# %%
classifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME',
                         learning_rate=0.8,
                             n_estimators=5)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8191666666666667

# %%
classifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME.R',
                         learning_rate=0.1,
                             n_estimators=5)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8191666666666667

# %%
classifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME.R',
                         learning_rate=0.8,
                             n_estimators=50)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8171666666666667

# %%
classifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME.R',
                         learning_rate=0.8,
                             n_estimators=10)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8186666666666667

# %% [markdown]
# ### Best Performing Model :

# %%
adaBoostClassifier = AdaBoostClassifier(random_state=42,
                         algorithm='SAMME.R',
                         learning_rate=0.01,
                             n_estimators=5)
adaBoostClassifier.fit(X_train, y_train)
predictions = adaBoostClassifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8191666666666667

# %%
adaBoostClassifier_result = train_predict(adaBoostClassifier, X_train.shape[0], X_train, y_train, X_test, y_test)
plot_cm(y_test, adaBoostClassifier.predict(X_test))
# Out:
# acc_train : 0.8197083333333334
# acc_test : 0.8191666666666667
# prec_train : 0.6968724939855654
# prec_test : 0.690251572327044
# f1_train : 0.4454696911444317
# f1_test : 0.44727457972491086
# recall_train : 0.3273686193256734
# recall_test : 0.3308214016578749
# auc_train : 0.6434606726182697
# auc_test : 0.6443321645567354
# f_train : 0.4454696911444317
# f_test : 0.44727457972491086
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89     18691
#            1       0.70      0.33      0.45      5309
#
#     accuracy                           0.82     24000
#    macro avg       0.77      0.64      0.67     24000
# weighted avg       0.80      0.82      0.79     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      4673
#            1       0.69      0.33      0.45      1327
#
# ...

# %% [markdown]
# # xgboost

# %%
xgb_classifier = XGBClassifier()
xgb_classifier.fit(X_train, y_train)
predictions = xgb_classifier.predict(X_test)
print(accuracy_score(y_true = y_test, y_pred = predictions))
# Out:
# 0.8141666666666667

# %%
xgb_classifier_result = train_predict(xgb_classifier, X_train.shape[0], X_train, y_train, X_test, y_test)
plot_cm(y_test, xgb_classifier.predict(X_test))
# Out:
# acc_train : 0.88425
# acc_test : 0.8141666666666667
# prec_train : 0.8707881629065338
# prec_test : 0.6452054794520548
# f1_train : 0.6814950699380876
# f1_test : 0.4579484686436558
# recall_train : 0.5598041062346958
# recall_test : 0.3549359457422758
# auc_train : 0.9449346828469174
# auc_test : 0.7622551007721085
# f_train : 0.6814950699380876
# f_test : 0.4579484686436558
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93     18691
#            1       0.87      0.56      0.68      5309
#
#     accuracy                           0.88     24000
#    macro avg       0.88      0.77      0.81     24000
# weighted avg       0.88      0.88      0.87     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      4673
#            1       0.65      0.35      0.46      1327
#
# ...

# %% [markdown]
# # lgbm Classifier :

# %%
lgbm=lgb.LGBMClassifier()

# %% [markdown]
# ### Best Performing Model :

# %%
lgbm.fit(X_train, y_train)
lgbm_result = train_predict(lgbm, X_train.shape[0], X_train, y_train, X_test, y_test)
plot_cm(y_test, lgbm.predict(X_test))
# Out:
# acc_train : 0.8441666666666666
# acc_test : 0.8168333333333333
# prec_train : 0.7583141257820217
# prec_test : 0.6553133514986376
# f1_train : 0.5518811406661873
# f1_test : 0.46676370693837943
# recall_train : 0.4337916745149746
# recall_test : 0.3624717407686511
# auc_train : 0.8848733926303459
# auc_test : 0.7760391712979904
# f_train : 0.5518811406661873
# f_test : 0.46676370693837943
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91     18691
#            1       0.76      0.43      0.55      5309
#
#     accuracy                           0.84     24000
#    macro avg       0.81      0.70      0.73     24000
# weighted avg       0.83      0.84      0.83     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.66      0.36      0.47      1327
#
# ...

# %%
lgbm.fit(X_train_scaled, y_train)
lgbm_result = train_predict(lgbm, X_train_scaled.shape[0], X_train_scaled, y_train, X_test_scaled, y_test)
plot_cm(y_test, lgbm.predict(X_test_scaled))
# Out:
# acc_train : 0.84275
# acc_test : 0.8181666666666667
# prec_train : 0.7560894227560894
# prec_test : 0.6634349030470914
# f1_train : 0.5456296653021911
# f1_test : 0.4675451439726696
# recall_train : 0.4268223770954982
# recall_test : 0.36096458176337604
# auc_train : 0.8836733283638273
# auc_test : 0.7780850275702376
# f_train : 0.5456296653021911
# f_test : 0.4675451439726696
# classification_report_train :               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.90     18691
#            1       0.76      0.43      0.55      5309
#
#     accuracy                           0.84     24000
#    macro avg       0.81      0.69      0.73     24000
# weighted avg       0.83      0.84      0.83     24000
#
# classification_report_test :               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.66      0.36      0.47      1327
#
# ...

# %% [markdown]
# # Feature Importance Plot (describes how much each feature Contributes) :

# %%
# randomforest, adaboost, xgb
def feature_importance_plot(clf):
    clf.predict(X_test_scaled)
    tmp = pd.DataFrame({'Feature': X_train.columns, 'Feature importance': clf.feature_importances_})
    tmp = tmp.sort_values(by='Feature importance',ascending=False)
    plt.figure(figsize = (16,4))
    plt.title('Features importance',fontsize=14)
    s = sns.barplot(x='Feature',y='Feature importance',data=tmp)
    s.set_xticklabels(s.get_xticklabels(),rotation=90)
    plt.show()# Feature Importance Plot (describes how much each feature Contributes) :

# %% [markdown]
# # Feature Importance Plot (Random Forest) :

# %%
feature_importance_plot(randomForest_classifier)

# %% [markdown]
# # Feature Importance Plot (XGB) :

# %%
fig, (ax) = plt.subplots(ncols=1, figsize=(8,5))
xgb.plot_importance(xgb_classifier, height=0.8, title="Features importance (XGBoost)", ax=ax, color="blue") 
plt.show()

# %% [markdown]
# # Feature Importance Plot (lgb) :

# %%
fig, (ax) = plt.subplots(ncols=1, figsize=(8,5))
lgb.plot_importance(lgbm, height=0.8, title="Features importance (LGB)", ax=ax, color="red") 
plt.show()

# %% [markdown]
# # Result compilation :

# %%
model_results=[
    logisticRegression_result,
    linear_svm_result,
    kernel_svm_result,
    gaussianNB_result,
    kNeighborsClassifier_result,
    baggingClassifier_result,
    sgdClassifier_result,
    decision_classifier_result,
    randomForest_classifier_result,
    adaBoostClassifier_result,
    xgb_classifier_result,
    lgbm_result
]

models = [
    "logisticRegression",
    "linear_svm",
    "kernel_svm",
    "gaussianNB",
    "kNeighborsClassifier",
    "baggingClassifier",
    "sgdClassifier",
    "decisionTreeClassifier",
    "randomForestClassifier",
    "adaBoostClassifier",
    "xgb_classifier",
    "lgbm",
]


training_data_results = {
    "model": models,
    "model_accuracy": [model_results[i]['acc_train'] for i in range(len(model_results))],
    "model_precision": [model_results[i]['prec_train'] for i in range(len(model_results))],    
    "model_f1": [model_results[i]['f1_train'] for i in range(len(model_results))],    
    "model_recall": [model_results[i]['recall_train'] for i in range(len(model_results))],    
    "model_accuracy": [model_results[i]['acc_train'] for i in range(len(model_results))],
    "model_fbeta":[model_results[i]["f_train"] for i in range(len(model_results))],
}

training_data_results["model_auc"] = []
for i in range(len(models)):
    try:
        training_data_results["model_auc"].append(model_results[i]['auc_train'])
    except:
        training_data_results["model_auc"].append(0)
    
testing_data_results = {
    "model": models,
    "model_accuracy": [model_results[i]['acc_test'] for i in range(len(model_results))],
    "model_precision": [model_results[i]['prec_test'] for i in range(len(model_results))],    
    "model_f1": [model_results[i]['f1_test'] for i in range(len(model_results))],    
    "model_recall": [model_results[i]['recall_test'] for i in range(len(model_results))],    
    "model_accuracy": [model_results[i]['acc_test'] for i in range(len(model_results))],    
    "model_fbeta":[model_results[i]["f_test"] for i in range(len(model_results))],
}

testing_data_results["model_auc"] = []
for i in range(len(models)):
    try:
        testing_data_results["model_auc"].append(model_results[i]['auc_train'])
    except:
        testing_data_results["model_auc"].append(0)
        
training_data_results = pd.DataFrame(training_data_results)
testing_data_results = pd.DataFrame(testing_data_results)

# %% [markdown]
# # Compiled Results for train and test dataset

# %%
training_data_results
# Out:
#                      model  model_accuracy  model_precision  model_f1  \
# 0       logisticRegression        0.811500         0.714130  0.366564
# 1               linear_svm        0.809875         0.705623  0.359399
# 2               kernel_svm        0.825375         0.707037  0.476714
# 3               gaussianNB        0.761417         0.468783  0.522356
# 4     kNeighborsClassifier        0.841000         0.718211  0.562887
# 5        baggingClassifier        0.980708         0.993885  0.954674
# 6            sgdClassifier        0.691833         0.325531  0.344907
# 7   decisionTreeClassifier        0.823125         0.681694  0.484642
# 8   randomForestClassifier        0.949250         0.999512  0.870481
# 9       adaBoostClassifier        0.819708         0.696872  0.445470
# 10          xgb_classifier        0.884250         0.870788  0.681495
# 11                    lgbm        0.842750         0.756089  0.545630
#
#     model_recall  model_fbeta  model_auc
# ...

# %%
testing_data_results
# Out:
#                      model  model_accuracy  model_precision  model_f1  \
# 0       logisticRegression        0.807833         0.688312  0.355506
# 1               linear_svm        0.808000         0.683438  0.361419
# 2               kernel_svm        0.816333         0.666667  0.449550
# 3               gaussianNB        0.752167         0.450860  0.496785
# 4     kNeighborsClassifier        0.791833         0.545455  0.428375
# 5        baggingClassifier        0.803333         0.599190  0.429400
# 6            sgdClassifier        0.687833         0.318000  0.337460
# 7   decisionTreeClassifier        0.818667         0.662144  0.472868
# 8   randomForestClassifier        0.817833         0.662050  0.466569
# 9       adaBoostClassifier        0.819167         0.690252  0.447275
# 10          xgb_classifier        0.814167         0.645205  0.457948
# 11                    lgbm        0.818167         0.663435  0.467545
#
#     model_recall  model_fbeta  model_auc
# ...

# %% [markdown]
# # Bar plots to Compare Model performances vs different metrics

# %%
def make_evaluation_plots(data_results,x_axis,y_axis):
    plt.figure(figsize=(12, 6))
    colors = plt.cm.tab20(np.linspace(0, 1, data_results.shape[0]))
    plt.bar(data_results[x_axis], data_results[y_axis], color = colors)
    plt.xticks(rotation=90, ha='right')
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)
    plt.title(f"{y_axis}")
    plt.tight_layout()

    # Display the plot
    plt.show()

# %%
eval_cols = training_data_results.columns
eval_cols
# Out:
# Index(['model', 'model_accuracy', 'model_precision', 'model_f1',
#        'model_recall', 'model_fbeta', 'model_auc'],
#       dtype='object')

# %% [markdown]
# # Bar plots to Compare Model performances vs different metrics over Training Data

# %%
for i in range(1,len(eval_cols)):
    make_evaluation_plots(training_data_results,eval_cols[0],eval_cols[i])

# %% [markdown]
# # Bar plots to Compare Model performances vs different metrics over Testing Data

# %%
for i in range(1,len(eval_cols)):
    make_evaluation_plots(testing_data_results,eval_cols[0],eval_cols[i])

# %% [markdown]
# # Best values obtained from all the models combined

# %%
# Best values obtained from all the models combined
testing_data_results.describe().T['max']
# Out:
# model_accuracy     0.819167
# model_precision    0.690252
# model_f1           0.496785
# model_recall       0.553127
# model_fbeta        0.496785
# model_auc          0.999150
# Name: max, dtype: float64

# %%
highest_values = testing_data_results.iloc[:, 1:].max()

# Find the corresponding value in the 'Name' column using idxmax()
highest_names = testing_data_results.iloc[:, 1:].idxmax()
highest_names = [testing_data_results["model"][i] for i in highest_names]
# Create a new DataFrame to store the result

result_df = pd.DataFrame({'Name': highest_names, 'Best Value': highest_values})

result_df
# Out:
#                                    Name  Best Value
# model_accuracy       adaBoostClassifier    0.819167
# model_precision      adaBoostClassifier    0.690252
# model_f1                     gaussianNB    0.496785
# model_recall                 gaussianNB    0.553127
# model_fbeta                  gaussianNB    0.496785
# model_auc        decisionTreeClassifier    0.999150

# %% [markdown]
# # BEST PERFORMER :

# %%
pd.DataFrame(testing_data_results.iloc[9,:]).T
# Out:
#                 model model_accuracy model_precision  model_f1 model_recall  \
# 9  adaBoostClassifier       0.819167        0.690252  0.447275     0.330821
#
#   model_fbeta model_auc
# 9    0.447275  0.643461

# %% [markdown]
# # BEST PERFORMER STATS ON TESTING DATA:

# %%
print(adaBoostClassifier_result['acc_test'])
print(adaBoostClassifier_result['classification_report_test'])
# Out:
# 0.8191666666666667
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      4673
#            1       0.69      0.33      0.45      1327
#
#     accuracy                           0.82      6000
#    macro avg       0.76      0.64      0.67      6000
# weighted avg       0.80      0.82      0.79      6000
